# %%
with open("filelists/bnslr_audio_text_test.txt", "r") as fr1:
    with open("SLRDATA/bn_slr_all_texts.txt", "r") as fr2:
        for i,r1 in enumerate(fr1):
            for j,r2 in enumerate(fr2):
                if r1.strip() in r2:
                    print(r2)
# Out:
# SLRDATA/wavs/0118626532.wav	পদযাত্রাটি আগারগাঁওয়ের

# %%
with open("SLRDATA/bn_slr_all_texts.txt", "r") as fr2:
    for j,r2 in enumerate(fr2):
        print(r2)
# Out:
# SLRDATA/wavs/cfc8d68583.wav	তাঁদের ছিল না
#
# SLRDATA/wavs/0987e381fa.wav	বাংলাদেশকে অভিন্ন নদীর পানি থেকে
#
# SLRDATA/wavs/84093a6b78.wav	বোয়িংয়ে কাজ করতেন
#
# SLRDATA/wavs/9505277a78.wav	কারণ সম্পর্কে
#
# SLRDATA/wavs/4393f9d316.wav	ফেটানো ডিম দিয়ে
#
# SLRDATA/wavs/ac0b249a71.wav	চলে যেতে বাধ্য আমি
#
# SLRDATA/wavs/f3f6c6a2e4.wav	ভর্তি পরীক্ষা স্থগিত হওয়াকে
#
# SLRDATA/wavs/f5bf4edbe2.wav	যদিও জ্ঞানম্ শব্দটি
#
# SLRDATA/wavs/7257eb8a86.wav	খুন হয়েছেন
#
# SLRDATA/wavs/a98053cd19.wav	এদিকে এই ঘটনায়
#
# SLRDATA/wavs/56d365b0b5.wav	মধ্যপ্রাচ্য বিভাগের গবেষক
#
# SLRDATA/wavs/6dc5f57716.wav	একদিনের আন্তর্জাতিক ক্রিকেটে
#
# SLRDATA/wavs/3bc33e8199.wav	পুরোদমে এগিয়ে চলছে
#
# SLRDATA/wavs/9ea90f4355.wav	যে-কথা ধ্যানধারণা
#
# SLRDATA/wavs/e23fb2c1dc.wav	চমেক পুলিশ ফাঁড়ির হাবিলদার
#
# SLRDATA/wavs/acb0af232e.wav	ডাবল ১ হাজার ২শ’ থেকে
#
# SLRDATA/wavs/029b62c0ee.wav	একুশের কৃষ্ণচূড়া
#
# SLRDATA/wavs/b99ca7061b.wav	দৈনিক সকালের খবর
#
# SLRDATA/wavs/f7f195e29e.wav	তাঁর এক দাদা ছাড়া
#
# ...
